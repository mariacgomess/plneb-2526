# %%
from gensim.models import Word2Vec
sentences=[['this','is','the','first','sentence','for','word2vec'],
           ['this','is','the','second','sentence'],
           ['yet','another','sentence']
           ]
model=Word2Vec(sentences, vector_size=100, window=5, min_count=1, sg=0, epochs=5, workers=3)
# Out:
# c:\Users\Maria\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.9) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %%
model.wv['sentence']
# Out:
# array([-5.3623732e-04,  2.3643578e-04,  5.1034451e-03,  9.0094414e-03,
#        -9.3031237e-03, -7.1169422e-03,  6.4589935e-03,  8.9731570e-03,
#        -5.0155222e-03, -3.7634422e-03,  7.3806429e-03, -1.5335002e-03,
#        -4.5366986e-03,  6.5541747e-03, -4.8602517e-03, -1.8160517e-03,
#         2.8766338e-03,  9.9189242e-04, -8.2853707e-03, -9.4489949e-03,
#         7.3119029e-03,  5.0703571e-03,  6.7578200e-03,  7.6287985e-04,
#         6.3510095e-03, -3.4054297e-03, -9.4641914e-04,  5.7686814e-03,
#        -7.5217788e-03, -3.9361771e-03, -7.5117229e-03, -9.3005964e-04,
#         9.5382975e-03, -7.3193042e-03, -2.3338124e-03, -1.9377774e-03,
#         8.0775889e-03, -5.9310072e-03,  4.5163288e-05, -4.7538229e-03,
#        -9.6037304e-03,  5.0073871e-03, -8.7597491e-03, -4.3919077e-03,
#        -3.5100642e-05, -2.9618701e-04, -7.6613836e-03,  9.6149230e-03,
#         4.9821516e-03,  9.2333164e-03, -8.1580700e-03,  4.4958824e-03,
#        -4.1371533e-03,  8.2455151e-04,  8.4987795e-03, -4.4622603e-03,
#         4.5175850e-03, -6.7870873e-03, -3.5485553e-03,  9.3986839e-03,
#        -1.5776822e-03,  3.2137759e-04, -4.1407077e-03, -7.6828320e-03,
#        -1.5080365e-03,  2.4698412e-03, -8.8804361e-04,  5.5337655e-03,
#        -2.7430286e-03,  2.2601075e-03,  5.4558967e-03,  8.3461097e-03,
#        -1.4537679e-03, -9.2083151e-03,  4.3706344e-03,  5.7179568e-04,
#         7.4420474e-03, -8.1329799e-04, -2.6384632e-03, -8.7531731e-03,
#        -8.5657294e-04,  2.8266162e-03,  5.4015298e-03,  7.0527885e-03,
#        -5.7032285e-03,  1.8588545e-03,  6.0889777e-03, -4.7981408e-03,
#        -3.1073187e-03,  6.7977570e-03,  1.6315063e-03,  1.8992065e-04,
#         3.4737024e-03,  2.1778156e-04,  9.6190069e-03,  5.0606988e-03,
#        -8.9175571e-03, -7.0416923e-03,  9.0147275e-04,  6.3926536e-03],
#       dtype=float32)

# %%
more_sentences=[['Advanced','users','can','load','a','model',
                 'and','continue','training','it','with','more','sentences','ds']
                 ]
model.build_vocab(more_sentences, update=True)
model.train(more_sentences, total_examples=model.corpus_count, epochs=model.epochs)
model.wv['Advanced']
# Out:
# array([ 7.0887972e-03, -1.5679300e-03,  7.9474989e-03, -9.4886590e-03,
#        -8.0294991e-03, -6.6403709e-03, -4.0034545e-03,  4.9892161e-03,
#        -3.8135587e-03, -8.3199050e-03,  8.4117772e-03, -3.7470020e-03,
#         8.6086961e-03, -4.8957514e-03,  3.9185942e-03,  4.9220170e-03,
#         2.3926091e-03, -2.8188038e-03,  2.8491246e-03, -8.2562361e-03,
#        -2.7655398e-03, -2.5911583e-03,  7.2490061e-03, -3.4634031e-03,
#        -6.5997029e-03,  4.3404270e-03, -4.7448516e-04, -3.5975564e-03,
#         6.8824720e-03,  3.8723124e-03, -3.9002013e-03,  7.7188847e-04,
#         9.1435025e-03,  7.7546560e-03,  6.3618720e-03,  4.6673026e-03,
#         2.3844899e-03, -1.8416261e-03, -6.3712932e-03, -3.0181051e-04,
#        -1.5653884e-03, -5.7228567e-04, -6.2628710e-03,  7.4340473e-03,
#        -6.5914928e-03, -7.2392775e-03, -2.7571463e-03, -1.5154004e-03,
#        -7.6357173e-03,  6.9824100e-04, -5.3261113e-03, -1.2755442e-03,
#        -7.3651113e-03,  1.9605684e-03,  3.2731986e-03, -2.3138524e-05,
#        -5.4483581e-03, -1.7260861e-03,  7.0849168e-03,  3.7362587e-03,
#        -8.8810492e-03, -3.4135508e-03,  2.3541022e-03,  2.1380198e-03,
#        -9.4640078e-03,  4.5711659e-03, -8.6569972e-03, -7.3870681e-03,
#         3.4831120e-03, -3.4709584e-03,  3.5644709e-03,  8.8940905e-03,
#        -3.5743224e-03,  9.3204249e-03,  1.7110384e-03,  9.8477742e-03,
#         5.7050432e-03, -9.1494834e-03, -3.3277308e-03,  6.5301750e-03,
#         5.6027793e-03,  8.7055154e-03,  6.9261026e-03,  8.0388878e-03,
#        -9.8230084e-03,  4.2988253e-03, -5.0300765e-03,  3.5123860e-03,
#         6.0566878e-03,  4.3921317e-03,  7.5123594e-03,  1.4977157e-03,
#        -1.2649416e-03,  5.7684006e-03, -5.6395675e-03,  3.8591625e-05,
#         9.4565870e-03, -5.4812501e-03,  3.8142789e-03, -8.1130210e-03],
#       dtype=float32)

# %%
len(model.wv)
# Out:
# 24

# %%
"sentence" in model.wv
# Out:
# True

# %%
model.wv.index_to_key
# Out:
# ['sentence',
#  'the',
#  'is',
#  'this',
#  'another',
#  'yet',
#  'second',
#  'word2vec',
#  'for',
#  'first',
#  'Advanced',
#  'users',
#  'can',
#  'load',
#  'a',
#  'model',
#  'and',
#  'continue',
#  'training',
#  'it',
#  'with',
#  'more',
#  'sentences',
#  'ds']

# %%
model.save("word2vec.model")

model=Word2Vec.load("word2vec.model")

# %%
from gensim.models import KeyedVectors

word_vectores = model.wv
word_vectores.save("word2vec.wordvectors")

wv = KeyedVectors.load("word2vec.wordvectors")
vector = wv['sentence']
print(vector)
# Out:
# [-5.3623732e-04  2.3643578e-04  5.1034451e-03  9.0094414e-03
#  -9.3031237e-03 -7.1169422e-03  6.4589935e-03  8.9731570e-03
#  -5.0155222e-03 -3.7634422e-03  7.3806429e-03 -1.5335002e-03
#  -4.5366986e-03  6.5541747e-03 -4.8602517e-03 -1.8160517e-03
#   2.8766338e-03  9.9189242e-04 -8.2853707e-03 -9.4489949e-03
#   7.3119029e-03  5.0703571e-03  6.7578200e-03  7.6287985e-04
#   6.3510095e-03 -3.4054297e-03 -9.4641914e-04  5.7686814e-03
#  -7.5217788e-03 -3.9361771e-03 -7.5117229e-03 -9.3005964e-04
#   9.5382975e-03 -7.3193042e-03 -2.3338124e-03 -1.9377774e-03
#   8.0775889e-03 -5.9310072e-03  4.5163288e-05 -4.7538229e-03
#  -9.6037304e-03  5.0073871e-03 -8.7597491e-03 -4.3919077e-03
#  -3.5100642e-05 -2.9618701e-04 -7.6613836e-03  9.6149230e-03
#   4.9821516e-03  9.2333164e-03 -8.1580700e-03  4.4958824e-03
#  -4.1371533e-03  8.2455151e-04  8.4987795e-03 -4.4622603e-03
#   4.5175850e-03 -6.7870873e-03 -3.5485553e-03  9.3986839e-03
#  -1.5776822e-03  3.2137759e-04 -4.1407077e-03 -7.6828320e-03
#  -1.5080365e-03  2.4698412e-03 -8.8804361e-04  5.5337655e-03
#  -2.7430286e-03  2.2601075e-03  5.4558967e-03  8.3461097e-03
#  -1.4537679e-03 -9.2083151e-03  4.3706344e-03  5.7179568e-04
#   7.4420474e-03 -8.1329799e-04 -2.6384632e-03 -8.7531731e-03
#  -8.5657294e-04  2.8266162e-03  5.4015298e-03  7.0527885e-03
#  -5.7032285e-03  1.8588545e-03  6.0889777e-03 -4.7981408e-03
#  -3.1073187e-03  6.7977570e-03  1.6315063e-03  1.8992065e-04
#   3.4737024e-03  2.1778156e-04  9.6190069e-03  5.0606988e-03
#  -8.9175571e-03 -7.0416923e-03  9.0147275e-04  6.3926536e-03]

# %%
word_vectores.save_word2vec_format('vector.txt',binary=False)
word_vectores.save_word2vec_format('vector.bin',binary=True)

# %%
import gensim.downloader
list(gensim.downloader.info()['models'].keys())
# Out:
# ['fasttext-wiki-news-subwords-300',
#  'conceptnet-numberbatch-17-06-300',
#  'word2vec-ruscorpora-300',
#  'word2vec-google-news-300',
#  'glove-wiki-gigaword-50',
#  'glove-wiki-gigaword-100',
#  'glove-wiki-gigaword-200',
#  'glove-wiki-gigaword-300',
#  'glove-twitter-25',
#  'glove-twitter-50',
#  'glove-twitter-100',
#  'glove-twitter-200',
#  '__testing_word2vec-matrix-synopsis']

# %%
model_wv=gensim.downloader.load('glove-twitter-25')
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %%
model_wv.most_similar('twitter')
# Out:
# [('facebook', 0.948005199432373),
#  ('tweet', 0.9403423070907593),
#  ('fb', 0.9342358708381653),
#  ('instagram', 0.9104824066162109),
#  ('chat', 0.8964964747428894),
#  ('hashtag', 0.8885937333106995),
#  ('tweets', 0.8878158330917358),
#  ('tl', 0.8778461217880249),
#  ('link', 0.8778210878372192),
#  ('internet', 0.8753897547721863)]

# %%
print(model_wv.similarity("olive","tree"))
print(model_wv.similarity("olive","animal"))
print(model_wv.similarity("olive","house"))
# Out:
# 0.8198055
# 0.5063875
# 0.6669966

# %%
pairs=[
    ('car','minivan'),
    ('car','bicycle'),
    ('car','airplane'),
    ('car','cereal'),
    ('car','communism'),
]
for w1, w2 in pairs:
    print('%s \t %s \t% .2f' % (w1,w2, model_wv.similarity(w1,w2)))
# Out:
# car 	 minivan 	 0.50
# car 	 bicycle 	 0.70
# car 	 airplane 	 0.73
# car 	 cereal 	 0.54
# car 	 communism 	 0.11

# %%
model_wv.doesnt_match(['portugal','france','russia'])
# Out:
# 'portugal'

# %%
model_wv.doesnt_match(['cat','dog','russia'])
# Out:
# 'russia'

# %%
result=model_wv.most_similar(positive=['woman','king'],negative=['man'])
print(result)
# Out:
# [('meets', 0.8841923475265503), ('prince', 0.832163393497467), ('queen', 0.8257461190223694), ('’s', 0.8174097537994385), ('crow', 0.813499391078949), ('hunter', 0.8131037950515747), ('father', 0.8115833401679993), ('soldier', 0.81113600730896), ('mercy', 0.8082392811775208), ('hero', 0.8082262277603149)]

# %%
result=model_wv.most_similar(positive=['hamburger','portugal'],negative=['u.s'])
print(result)
# Out:
# [('rum', 0.7173249125480652), ('vert', 0.6894827485084534), ('noel', 0.6865940690040588), ('kinder', 0.6784651875495911), ('principe', 0.6771542429924011), ('jean', 0.6754062175750732), ('café', 0.66560959815979), ('enzo', 0.6604594588279724), ('kebab', 0.659348726272583), ('poulet', 0.657860517501831)]

# %%
model_wv.most_similar("portugal",topn=50)
# Out:
# [('benfica', 0.8906856179237366),
#  ('inter', 0.8823169469833374),
#  ('barcelona', 0.8823107481002808),
#  ('milan', 0.8798957467079163),
#  ('bayern', 0.8668390512466431),
#  ('vs', 0.8622055649757385),
#  ('spain', 0.8606054186820984),
#  ('juventus', 0.8564385175704956),
#  ('porto', 0.8555518388748169),
#  ('manchester', 0.8532637357711792),
#  ('atletico', 0.8528964519500732),
#  ('dortmund', 0.8508117198944092),
#  ('munich', 0.8483925461769104),
#  ('malaga', 0.843699038028717),
#  ('borussia', 0.8435484766960144),
#  ('champions', 0.843521237373352),
#  ('chelsea', 0.8393116593360901),
#  ('tottenham', 0.8385051488876343),
#  ('barça', 0.8359622359275818),
#  ('psg', 0.8345885276794434),
#  ('newcastle', 0.8327121734619141),
#  ('derby', 0.828357458114624),
#  ('europa', 0.8278909921646118),
#  ('uruguay', 0.8266362547874451),
#  ('wembley', 0.8265668153762817),
#  ('everton', 0.8251709342002869),
#  ('nadal', 0.8236018419265747),
#  ('zenit', 0.8232069611549377),
#  ('liverpool', 0.8230037689208984),
#  ('madrid', 0.8221689462661743),
#  ('celtic', 0.8215534090995789),
#  ('eurovision', 0.8204659819602966),
#  ('napoli', 0.8183072805404663),
#  ('united', 0.8173773288726807),
#  ('barca', 0.8172615766525269),
#  ('italy', 0.8157469034194946),
#  ('juve', 0.8139891624450684),
#  ('mallorca', 0.8125426769256592),
#  ('cfc', 0.8123466968536377),
#  ('federer', 0.8118732571601868),
#  ('denmark', 0.8094380497932434),
#  ('lazio', 0.808518648147583),
#  ('wigan', 0.807966411113739),
#  ('ucl', 0.8041728138923645),
#  ('arsenal', 0.8039525151252747),
#  ('serbia', 0.8039079308509827),
#  ('roma', 0.8038486242294312),
#  ('siena', 0.8030058741569519),
#  ('sunderland', 0.8024166822433472),
#  ('villa', 0.8021950721740723)]

# %%
def analogy(x2,y1,x1):
    result=model_wv.most_similar(positive=[y1,x2], negative=[x1])
    return result[0][0]
