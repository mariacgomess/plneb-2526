# %%
from gensim.models import Word2Vec
import re
import spacy

nlp = spacy.load("pt_core_news_sm")
documentos=["Harry_Potter_Camara_Secreta-br.txt","Harry_Potter_e_A_Pedra_Filosofal.txt"]
sentences = []
for doc in documentos:
    f = open(doc,"r", encoding="utf8") 
    texto = f.read()
    texto = re.sub(r'\f', '', texto)
    doc = nlp(texto)
    for sent in doc.sents:
        # Get the text of each token, lowercased, filtering out punctuation
        tokens = [token.text.lower() for token in sent if not token.is_punct and not token.is_space]
        if len(tokens) > 0:
            sentences.append(tokens)

model = Word2Vec(sentences, vector_size=100, window=5, min_count=2, sg=0, epochs=5, workers=3)

# %%
model.wv.most_similar("harry")
# Out:
# [('hermione', 0.9953293204307556),
#  ('rony', 0.9951663017272949),
#  ('voz', 0.9902327656745911),
#  ('olhou', 0.9888575673103333),
#  ('abriu', 0.9880073666572571),
#  ('olhando', 0.9877097606658936),
#  ('cara', 0.9875636100769043),
#  ('quando', 0.9873300790786743),
#  ('hagrid', 0.9870768785476685),
#  ('ansioso', 0.986823558807373)]

# %%
print(model.wv.similarity("harry","rony"))
print(model.wv.similarity("harry","hermione"))
print(model.wv.similarity("harry","sonserina"))
print(model.wv.similarity("harry","grifinória"))
# Out:
# 0.99516624
# 0.9953293
# 0.97273034
# 0.9604521

# %%
result=model.wv.most_similar(positive=['harry','sonserina'],negative=['draco'])
print(result)
# Out:
# [('virou', 0.993669867515564), ('hermione', 0.9932264685630798), ('voz', 0.9931102991104126), ('abriu', 0.9929324984550476), ('varinha', 0.9929083585739136), ('quando', 0.9927428960800171), ('olhou', 0.9925091862678528), ('sra.', 0.9924017786979675), ('cara', 0.9922928214073181), ('sentou', 0.9922900199890137)]

# %%
#aumentar o vector_size
from gensim.models import Word2Vec
import re
import spacy

nlp = spacy.load("pt_core_news_sm")
documentos=["Harry_Potter_Camara_Secreta-br.txt","Harry_Potter_e_A_Pedra_Filosofal.txt"]
sentences = []
for doc in documentos:
    f = open(doc,"r", encoding="utf8") 
    texto = f.read()
    texto = re.sub(r'\f', '', texto)
    doc = nlp(texto)
    for sent in doc.sents:
        # Get the text of each token, lowercased, filtering out punctuation
        tokens = [token.text.lower() for token in sent if not token.is_punct and not token.is_space]
        if len(tokens) > 0:
            sentences.append(tokens)

model = Word2Vec(sentences, vector_size=200, window=5, min_count=2, sg=0, epochs=5, workers=3)

# %%
model.wv.most_similar("harry")
# Out:
# [('hermione', 0.9989741444587708),
#  ('voz', 0.9967596530914307),
#  ('olhou', 0.9947781562805176),
#  ('rony', 0.9945085644721985),
#  ('quando', 0.9944723844528198),
#  ('abriu', 0.9943291544914246),
#  ('com', 0.9941019415855408),
#  ('perguntou', 0.993878960609436),
#  ('virou', 0.993801474571228),
#  ('rispidez', 0.9931269884109497)]

# %%
print(model.wv.similarity("harry","rony"))
print(model.wv.similarity("harry","hermione"))
print(model.wv.similarity("harry","sonserina"))
print(model.wv.similarity("harry","grifinória"))
# Out:
# 0.9945085
# 0.998974
# 0.9827422
# 0.9757779

# %%
result=model.wv.most_similar(positive=['harry','sonserina'],negative=['draco'])
print(result)
# Out:
# [('varinha', 0.9977128505706787), ('quando', 0.9967653155326843), ('com', 0.9967237710952759), ('olhou', 0.996527373790741), ('sacudiu', 0.9964855313301086), ('abriu', 0.9963863492012024), ('virou', 0.9963812828063965), ('mão', 0.9961798787117004), ('profa', 0.9952902793884277), ('fechou', 0.9952889680862427)]

# %%
#aumentar epochs
from gensim.models import Word2Vec
import re
import spacy

nlp = spacy.load("pt_core_news_sm")
documentos=["Harry_Potter_Camara_Secreta-br.txt","Harry_Potter_e_A_Pedra_Filosofal.txt"]
sentences = []
for doc in documentos:
    f = open(doc,"r", encoding="utf8") 
    texto = f.read()
    texto = re.sub(r'\f', '', texto)
    doc = nlp(texto)
    for sent in doc.sents:
        # Get the text of each token, lowercased, filtering out punctuation
        tokens = [token.text.lower() for token in sent if not token.is_punct and not token.is_space]
        if len(tokens) > 0:
            sentences.append(tokens)

model = Word2Vec(sentences, vector_size=200, window=8, min_count=2, sg=0, epochs=30, workers=3)

# %%
model.wv.most_similar("harry")
# Out:
# [('ele', 0.5510688424110413),
#  ('presidente', 0.48047927021980286),
#  ('dobby', 0.4754118025302887),
#  ('colin', 0.4684993326663971),
#  ('escapar', 0.4676026403903961),
#  ('portão', 0.4511418640613556),
#  ('mione', 0.4430951178073883),
#  ('desesperado', 0.4306451082229614),
#  ('neville', 0.4292639493942261),
#  ('ela', 0.41112858057022095)]

# %%
print(model.wv.similarity("harry","rony"))
print(model.wv.similarity("harry","hermione"))
print(model.wv.similarity("harry","sonserina"))
print(model.wv.similarity("harry","grifinória"))
# Out:
# 0.29676574
# 0.31380966
# -0.065463334
# 0.13490355

# %%
result=model.wv.most_similar(positive=['harry','sonserina'],negative=['draco'])
print(result)
# Out:
# [('grifinória', 0.5901100039482117), ('corvinal', 0.5491655468940735), ('partida', 0.5288211107254028), ('lufa-lufa', 0.5166301131248474), ('cerimônia', 0.5133864283561707), ('posse', 0.493935763835907), ('torre', 0.4821150600910187), ('quadribol', 0.4711887538433075), ('estação', 0.4607831537723541), ('escola', 0.4572901427745819)]

# %%
#aumentar sg
from gensim.models import Word2Vec
import re
import spacy

nlp = spacy.load("pt_core_news_sm")
documentos=["Harry_Potter_Camara_Secreta-br.txt","Harry_Potter_e_A_Pedra_Filosofal.txt"]
sentences = []
for doc in documentos:
    f = open(doc,"r", encoding="utf8") 
    texto = f.read()
    texto = re.sub(r'\f', '', texto)
    doc = nlp(texto)
    for sent in doc.sents:
        # Get the text of each token, lowercased, filtering out punctuation
        tokens = [token.text.lower() for token in sent if not token.is_punct and not token.is_space]
        if len(tokens) > 0:
            sentences.append(tokens)

model = Word2Vec(sentences, vector_size=200, window=8, min_count=2, sg=1, epochs=30, workers=3)

# %%
model.wv.most_similar("casa")
# Out:
# [('receberá', 0.4391084909439087),
#  ('seriamente', 0.4332394301891327),
#  ('deveres', 0.42487794160842896),
#  ('estiverem', 0.4197121858596802),
#  ('majorca', 0.4189653992652893),
#  ('acreditou', 0.41181132197380066),
#  ('acontecerem', 0.40839165449142456),
#  ('expulsá-los', 0.4057203531265259),
#  ('amanhã', 0.39730873703956604),
#  ('honra', 0.3963235914707184)]

# %%
model.wv.most_similar("harry")
# Out:
# [('abobado', 0.47151875495910645),
#  ('observando-a', 0.4555642306804657),
#  ('expelliarmus', 0.45225289463996887),
#  ('rony', 0.4382351338863373),
#  ('grunhiu', 0.43668726086616516),
#  ('pensativa', 0.43638095259666443),
#  ('enchendo-se', 0.43351316452026367),
#  ('portão', 0.43286362290382385),
#  ('esganiçando', 0.43148717284202576),
#  ('encarando-o', 0.4291878938674927)]

# %%
print(model.wv.similarity("harry","rony"))
print(model.wv.similarity("harry","hermione"))
print(model.wv.similarity("harry","sonserina"))
print(model.wv.similarity("harry","grifinória"))
# Out:
# 0.43823513
# 0.18233854
# 0.115225405
# 0.12361184

# %%
result=model.wv.most_similar(positive=['harry','sonserina'],negative=['draco'])
print(result)
# Out:
# [('seriamente', 0.3711564838886261), ('enche', 0.368888795375824), ('bordas', 0.3632937967777252), ('espião', 0.3575756251811981), ('reserva', 0.3531574010848999), ('posse', 0.3453211784362793), ('tomado', 0.33798596262931824), ('espionando', 0.3344062268733978), ('torcida', 0.33301255106925964), ('derrota', 0.3291805684566498)]

# %%
model.wv.save_word2vec_format('model_harry.txt', binary=False)

# %%
# !python -m gensim.scripts.word2vec2tensor -i model_harry.txt -o model_harry
# Out:
# c:\Users\Maria\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.9) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# 2026-04-27 17:36:37,119 - word2vec2tensor - INFO - running c:\Users\Maria\AppData\Local\Programs\Python\Python310\lib\site-packages\gensim\scripts\word2vec2tensor.py -i model_harry.txt -o model_harry
# 2026-04-27 17:36:37,119 - keyedvectors - INFO - loading projection weights from model_harry.txt
# 2026-04-27 17:36:38,494 - utils - INFO - KeyedVectors lifecycle event {'msg': 'loaded (6989, 200) matrix of type float32 from model_harry.txt', 'binary': False, 'encoding': 'utf8', 'datetime': '2026-04-27T17:36:38.483058', 'gensim': '4.4.0', 'python': '3.10.9 (tags/v3.10.9:1dd9be6, Dec  6 2022, 20:01:21) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26200-SP0', 'event': 'load_word2vec_format'}
# 2026-04-27 17:36:39,434 - word2vec2tensor - INFO - 2D tensor file saved to model_harry_tensor.tsv
# 2026-04-27 17:36:39,434 - word2vec2tensor - INFO - Tensor metadata file saved to model_harry_metadata.tsv
# 2026-04-27 17:36:39,435 - word2vec2tensor - INFO - finished running word2vec2tensor.py
